# %%
# !pip install matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from PIL import Image

# %%
dir = 'C:/Users/Luan/ThiGiacMayTinhSo7/img/00304.jpg'
# đọc ảnh
img = Image.open(dir)
plt.imshow(img)

# %%
# vẽ đồ thị cơ bản

# %%
x = [1,20,3,40,5]

# %%
y = [20,4,60,8,100]

# %%
plt.plot(x,y, 'red')
plt.title("Biểu đồ")
plt.show()

# %%
x = [100,200,30,400,50,600,70,800]
y = [100,20,400,50,700,80,850,550]

plt.imshow(img)
plt.plot(x,y, 'bo--') #b là màu xanh. o là điểm tròn. -- là đường nét đứt
plt.title("Biểu đồ xanh")
plt.show()
