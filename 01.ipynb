# %%
# Dấu # dùng để ghi chú
# Shift+ Enter : RUN đoạn code và thêm dòng mới

# %%
# Ctrl + ENter: RUN đoạn code và k thêm hàng mới

# %%
#!pip install pillow

# %%
# Thêm thư viện
from PIL import Image

# %%
# Khai báo một chứa thư mục (trong python phải dùng / và \\, (\) là sai)
dir = 'C:\Users\Luan\ThiGiacMayTinhSo7\img'
# Out:
#   Cell In[8], line 2
#     dir = 'C:\Users\Luan\ThiGiacMayTinhSo7\img'
#           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
dir = 'C:/Users/Luan/ThiGiacMayTinhSo7/img'

# %%
# Khai báo dường dẫn ảnh

# %%
image_path = dir + "01.JPG"
print(image_path)
# Out:
# C:/Users/Luan/ThiGiacMayTinhSo7/img01.JPG

# %%
img01 = Image.open(image_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 img01 = Image.open(image_path)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Luan\\ThiGiacMayTinhSo7\\img01.JPG'

# %%
image_path = dir + "/01.JPG"
print(image_path)
# Out:
# C:/Users/Luan/ThiGiacMayTinhSo7/img/01.JPG

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
image_path = dir + "/02.JPG"
print(image_path)
# Out:
# C:/Users/Luan/ThiGiacMayTinhSo7/img/02.JPG

# %%
img02 = Image.open(image_path)

# %%
display(img02)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
# In thông tin cơ bản 
print("định dạng : " + img01.format)
# Out:
# định dạng : JPEG

# %%
print("định dạng : " + img02.format)
# Out:
# định dạng : JPEG

# %%
print("kích thước ảnh : " + img01.size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print("kích thước ảnh : " + img01.size)
#
# TypeError: can only concatenate str (not "tuple") to str

# %%
print("kích thước ảnh : ", img01.size)
# Out:
# kích thước ảnh :  (720, 481)

# %%
# Lưu và chuyển đổi ảnh
new_img_01_path = dir + '/Luan_01.JPG'
new_img_PNG_01_path = dir + '/Luan_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 4
#       2 new_img_01_path = dir + '/new_01.JPG'
#       3 new_img_PNG_01_path = dir + '/new_01.PNG'
# ----> 4 img01.save(new_img_01_path)
#       5 img01.save(new_img_PNG_01_path)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2421, in Image.save(self, fp, format, **params)
#    2418     filename = os.path.realpath(os.fspath(fp.name))
#    2420 # may mutate self!
# -> 2421 self._ensure_mutable()
#    2423 save_all = params.pop("save_all", False)
#    2424 self.encoderinfo = params
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:597, in Image._ensure_mutable(self)
#     595     self._copy()
#     596 else:
# --> 597     self.load()
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageFile.py:182, in ImageFile.load(self)
#     179     msg = "cannot load this image"
#     180     raise OSError(msg)
# ...

# %%
img01.close()

# %%
dir = 'C:/Users/Luan/ThiGiacMayTinhSo7/img'

# %%
new_img_02_path = dir + '/Manh_02.JPG'
new_img_PNG_02_path = dir + '/Manh_02.PNG'
img02.save(new_img_02_path)
img02.save(new_img_PNG_02_path)

# %%
# Lưu và chuyển đổi ảnh
new_img_01_path = dir + '/Luan_01.JPG'
new_img_PNG_01_path = dir + '/Luan_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 new_img_01_path = dir + '/Luan_01.JPG'
#       3 new_img_PNG_01_path = dir + '/Luan_01.PNG'
# ----> 4 img01.save(new_img_01_path)
#       5 img01.save(new_img_PNG_01_path)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2421, in Image.save(self, fp, format, **params)
#    2418     filename = os.path.realpath(os.fspath(fp.name))
#    2420 # may mutate self!
# -> 2421 self._ensure_mutable()
#    2423 save_all = params.pop("save_all", False)
#    2424 self.encoderinfo = params
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:597, in Image._ensure_mutable(self)
#     595     self._copy()
#     596 else:
# --> 597     self.load()
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageFile.py:182, in ImageFile.load(self)
#     179     msg = "cannot load this image"
#     180     raise OSError(msg)
# ...

# %%
new_img_02_path = dir + '/Manh_02.JPG'
new_img_PNG_02_path = dir + '/Manh_02.PNG'
img02.save(new_img_02_path)
img02.save(new_img_PNG_02_path)

# %%
new_img_01_path = dir + '/Luan_01.JPG'
new_img_PNG_01_path = dir + '/Luan_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 3
#       1 new_img_01_path = dir + '/Luan_01.JPG'
#       2 new_img_PNG_01_path = dir + '/Luan_01.PNG'
# ----> 3 img01.save(new_img_01_path)
#       4 img01.save(new_img_PNG_01_path)
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:2421, in Image.save(self, fp, format, **params)
#    2418     filename = os.path.realpath(os.fspath(fp.name))
#    2420 # may mutate self!
# -> 2421 self._ensure_mutable()
#    2423 save_all = params.pop("save_all", False)
#    2424 self.encoderinfo = params
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:597, in Image._ensure_mutable(self)
#     595     self._copy()
#     596 else:
# --> 597     self.load()
#
# File ~\anaconda3\Lib\site-packages\PIL\ImageFile.py:182, in ImageFile.load(self)
#     179     msg = "cannot load this image"
#     180     raise OSError(msg)
# ...

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
image_path = dir + "/01.JPG"
print(image_path)
# Out:
# C:/Users/Luan/ThiGiacMayTinhSo7/img/01.JPG

# %%
img01 = Image.open(image_path)
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
new_img_01_path = dir + '/Luan_01.JPG'
new_img_PNG_01_path = dir + '/Luan_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_PNG_01_path)

# %%
new_img_02_path = dir + '/Manh_02.JPG'
new_img_PNG_02_path = dir + '/Manh_02.PNG'
img02.save(new_img_02_path)
img02.save(new_img_PNG_02_path)
