# %%
from PIL import Image
from imgtools import *

# %%
my_part = 'C:/Users/Luan/ThiGiacMayTinhSo7/img/03.jpg'

# %%
img = load_image(my_part)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
print(img.size)
# Out:
# (720, 481)

# %%
new_size = (1000,1000)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
new_img_01_path = dir + '/Luan_03.JPG'
img01.save(new_img_01_path)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 new_img_01_path = dir + '/Luan_03.JPG'
#       2 img01.save(new_img_01_path)
#
# TypeError: unsupported operand type(s) for +: 'builtin_function_or_method' and 'str'

# %%
dir = 'C:/Users/Luan/ThiGiacMayTinhSo7/img'

# %%
new_img_01_path = dir + '/Luan_03.JPG'
img.save(new_img_01_path)

# %%
thumbnail_size = (50,50)
img.thumbnail(thumbnail_size)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x33>

# %%
new_img_01_path = dir + '/Luan_Tt_03.JPG'
img.save(new_img_01_path)
