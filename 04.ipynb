# %%
from PIL import Image
from imgtools import *

# %%
my_part = 'C:/Users/Luan/ThiGiacMayTinhSo7/img/03.jpg'

# %%
img = load_image(my_part)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
# định vị khu vực cắt
region = (100, 75, 175, 150)
# cắt vùng ảnh
cropped_image = img.crop(region) #hàm crop dderr cắt ảnh

# %%
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x75>

# %%
# dán ảnh

# %%
#xác định vị trí cần dán
paste_position = (150, 150)
img.paste(cropped_image, paste_position)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>

# %%
paste_position = (150, 250)
img.paste(cropped_image, paste_position)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481>
